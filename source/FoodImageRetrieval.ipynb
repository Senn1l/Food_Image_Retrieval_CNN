# %% [markdown]
# # 0/ Cấp quyền truy cập

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # 1/ Thư viện

# %% [markdown]
# Phải restart runtime mới qua bước tiếp theo

# %%
# !pip install numpy
# !pip install matplotlib
# !pip install os
# !pip install h5py
# !pip install argparse
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement os (from versions: none)
# ERROR: No matching distribution found for os
# ...

# %% [markdown]
# # 2/ Rút trích đặc trưng

# %%
# %cd /content/gdrive/MyDrive/Colab\ Notebooks/flask-keras-cnn-image-retrieval
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/flask-keras-cnn-image-retrieval

# %%
# Trích xuất đặc trưng từ database lưu vào file .h5 cho 2 mô hình
# python index.py -database <path/to/database> -index <path/to/index> -model <model name>
# !python index.py -database database_large -index foodFeature_VGG16_L.h5 -model VGG16
# !python index.py -database database_large -index foodFeature_Resnet_L.h5 -model ResNet
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# extracting feature from image No. 7402 , 9900 images in total
# 1/1 [==============================] - 0s 23ms/step
# extracting feature from image No. 7403 , 9900 images in total
# 1/1 [==============================] - 0s 37ms/step
# extracting feature from image No. 7404 , 9900 images in total
# 1/1 [==============================] - 0s 30ms/step
# extracting feature from image No. 7405 , 9900 images in total
# 1/1 [==============================] - 0s 24ms/step
# extracting feature from image No. 7406 , 9900 images in total
# 1/1 [==============================] - 0s 34ms/step
# extracting feature from image No. 7407 , 9900 images in total
# 1/1 [==============================] - 0s 22ms/step
# extracting feature from image No. 7408 , 9900 images in total
# 1/1 [==============================] - 0s 22ms/step
# extracting feature from image No. 7409 , 9900 images in total
# ...

# %% [markdown]
# # 3/ Truy vấn <br>
# query là ảnh test <br>
# index là tập vector đặc trưng (file .h5) <br>
# result là nơi cần truy vấn

# %%
# %cd /content/gdrive/MyDrive/Colab\ Notebooks/flask-keras-cnn-image-retrieval
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/flask-keras-cnn-image-retrieval

# %%
# Lấy ảnh test
# apple_pie_test.png
# burger_test.png
# pizza_test.png
# ice_cream_test.png
# sushi_test.png

# hot_dog.png
# omelette.png
# cheesecake.png

# python query.py -query <path/to/query/image> -index <path/to/index> -result <path/to/result> -model <model name> -database <path/to/database> -n 10
# !python query.py -query testImage/hot_dog.png -index foodFeature_VGG16_L.h5 -model VGG16 -database database_large -n 10
# !python query.py -query testImage/hot_dog.png -index foodFeature_Resnet_L.h5 -model ResNet -database database_large -n 10
# Out:
# 2024-08-17 12:36:31.024811: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-17 12:36:31.067353: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-17 12:36:31.079272: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-17 12:36:31.108374: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# # 4/ Đánh giá mô hình

# %%
# %cd /content/gdrive/MyDrive/Colab\ Notebooks/flask-keras-cnn-image-retrieval
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/flask-keras-cnn-image-retrieval

# %%
# !python evaluate_precision.py -index foodFeature_VGG16_L.h5 -model VGG16 -database database_large
# Out:
# 2024-08-17 15:20:15.987643: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-17 15:20:16.008742: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-17 15:20:16.015077: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-17 15:20:16.032951: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python evaluate_precision.py -index foodFeature_Resnet_L.h5 -model ResNet -database database_large
# Out:
# 2024-08-17 16:36:43.079667: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-17 16:36:43.100204: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-17 16:36:43.106407: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-17 16:36:43.122631: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python evaluate_mAP.py -index foodFeature_VGG16_L.h5 -model VGG16 -database database_large
# Out:
# 2024-08-17 17:01:30.191144: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-17 17:01:30.211230: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-17 17:01:30.217256: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-17 17:01:30.232500: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python evaluate_mAP.py -index foodFeature_Resnet_L.h5 -model ResNet -database database_large
# Out:
# 2024-08-17 17:22:07.761537: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-17 17:22:07.781298: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-17 17:22:07.787460: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-17 17:22:07.802021: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
